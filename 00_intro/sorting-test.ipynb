# %%
# !pip install sorting
# Out:
# ...
#   Created wheel for sorting: filename=sorting-1.0.3-cp37-none-any.whl size=5882 sha256=81c074ee7889bfddfca94df1dd486de5182bf64e48033ce0f2ecdb77e7376def
#   Stored in directory: /root/.cache/pip/wheels/eb/f9/9d/ea128e53c92937b3f10b15f961f100068615df83d0b7c3affc
# Successfully built sorting
# ...

# %%
import sorting

lista = [1,56,23,1,6,8,3,2]
sorting.bubble(lista)
# Out:
# [1, 1, 2, 3, 6, 8, 23, 56]
