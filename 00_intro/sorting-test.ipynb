# %%
# !pip install sorting
# Out:
# ...
#   Created wheel for sorting: filename=sorting-1.0.3-cp37-none-any.whl size=5882 sha256=f16eacde1d25c31d5f7512ef3455652bb3016eec9289071dedd74cb8b9d75312
#   Stored in directory: /root/.cache/pip/wheels/eb/f9/9d/ea128e53c92937b3f10b15f961f100068615df83d0b7c3affc
# Successfully built sorting
# ...

# %%
import sorting

lista = [1,56,23,1,6,8,3,2]
sorting.bubble(lista)
# Out:
# [1, 1, 2, 3, 6, 8, 23, 56]
